# %% [markdown]
# <a href="https://colab.research.google.com/github/Dibakar88/Dibakar88/blob/main/MCDA_research_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Social indicator normalization**

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import os

# %%
df=pd.read_excel ("/content/Normalization.xlsx")

# %%
df
# Out:
#                                                  Zila  Bagerhat  Barguna  \
# 0                     Population density (per sqr km)    373.00   488.00
# 1                Percent of Population 14 or younger      32.15    34.10
# 2               Population ages 65 and above (%) (WB)      6.50     5.90
# 3     Percentage  Education (Secondary completed)(WB)     12.80    11.10
# 4                   Percentage of Earthen Roads(LGED)     62.00    76.81
# 5   Number of people against single healthcare pro...   2806.08  5222.22
# 6                        Access to mobile(haque,2020)      6.30    10.00
# 7                 Households with Electricity (%)(WB)     40.70    29.00
# 8   Households without toilet, open defecation (%)...      1.90     2.60
# 9                 Percent employed in agriculture(WB)     56.30    64.20
# 10         Percentage Households with safe water (WB)     15.78    21.42
# 11           extreme Poverty headcount ratio (%) (WB)     42.80    19.00
# ...

# %% [markdown]
# ### **Normalization**

# %%
df.drop([" Zila"], axis=1, inplace=True)

# %%
df.head()
# Out:
#    Bagerhat  Barguna  Barisal   Bhola  Chandpur  Chittagong  Cox's Bazar  \
# 0    373.00   488.00   840.00  522.00   1468.00     1442.00       919.00
# 1     32.15    34.10    35.95   40.60     37.13       34.09        43.22
# 2      6.50     5.90     5.70    4.70      5.90        3.80         3.20
# 3     12.80    11.10    15.20    8.80     12.90       19.10         8.60
# 4     62.00    76.81    72.53   55.12     63.43       66.01        65.20
#
#      Feni  Gopalganj  Jessore  Jhalakati  Khulna  Lakshmipur  Narail  \
# 0  1451.0     798.00  1060.00     966.00  528.00     1200.00   746.0
# 1    35.3      37.25    30.80      34.54   29.92       39.39    34.9
# 2     5.5       5.50     5.20       6.60    5.30        5.10     5.8
# 3    17.0      11.00    13.40      17.10   16.80       10.40    11.3
# 4    47.2      52.00    64.71      73.21   50.10       66.40    66.0
#
#    Noakhali  Patuakhali  Pirozpur  Satkhira  Shariatpur
# ...

# %%
#scaling with MinMaxScaler
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit (df)
scaled = pd.DataFrame(scaler.transform(df),columns=df.columns)
scaled
# Out:
#     Bagerhat   Barguna   Barisal     Bhola  Chandpur  Chittagong  Cox's Bazar  \
# 0   0.132338  0.092995  0.538430  0.076625  0.395854    0.882333     0.228784
# 1   0.010787  0.006035  0.022183  0.005318  0.009512    0.019722     0.010308
# 2   0.001640  0.000632  0.002761  0.000000  0.001080    0.001164     0.000324
# 3   0.003887  0.001628  0.008860  0.000607  0.002970    0.010538     0.001671
# 4   0.021432  0.014218  0.045670  0.007468  0.016613    0.039279     0.015791
# 5   1.000000  1.000000  1.000000  1.000000  1.000000    1.000000     1.000000
# 6   0.001569  0.001418  0.005522  0.000785  0.000000    0.000000     0.000000
# 7   0.013836  0.005058  0.033772  0.003214  0.014472    0.047422     0.007534
# 8   0.000000  0.000000  0.000000  0.000222  0.000189    0.000368     0.002470
# 9   0.019400  0.011802  0.032039  0.009287  0.013365    0.009558     0.011775
# 10  0.004950  0.003606  0.012771  0.002299  0.004847    0.010446     0.003647
# ...

# %%
scaled
# Out:
#     Bagerhat   Barguna   Barisal     Bhola  Chandpur  Chittagong  Cox's Bazar  \
# 0   0.132338  0.092995  0.538430  0.076625  0.395854    0.882333     0.228784
# 1   0.010787  0.006035  0.022183  0.005318  0.009512    0.019722     0.010308
# 2   0.001640  0.000632  0.002761  0.000000  0.001080    0.001164     0.000324
# 3   0.003887  0.001628  0.008860  0.000607  0.002970    0.010538     0.001671
# 4   0.021432  0.014218  0.045670  0.007468  0.016613    0.039279     0.015791
# 5   1.000000  1.000000  1.000000  1.000000  1.000000    1.000000     1.000000
# 6   0.001569  0.001418  0.005522  0.000785  0.000000    0.000000     0.000000
# 7   0.013836  0.005058  0.033772  0.003214  0.014472    0.047422     0.007534
# 8   0.000000  0.000000  0.000000  0.000222  0.000189    0.000368     0.002470
# 9   0.019400  0.011802  0.032039  0.009287  0.013365    0.009558     0.011775
# 10  0.004950  0.003606  0.012771  0.002299  0.004847    0.010446     0.003647
# ...

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
x = pd.DataFrame (scaled)
x.to_excel(excel_writer=r'/content/gdrive/MyDrive/Py_practice/MCDA.xlsx')
